# %% [markdown]
# <a href="https://colab.research.google.com/github/carloslme/thinkstats2_exercises/blob/main/testing_data_on_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# # Description
# The data collected is from the US Centers for Disease Control and Prevention (CDC), and is called **National Survey of Family Growth (NSFG)**, which is intended to gather "information on family life, marriage and divorce, pregnancy, infertility, use of contraception, and men's and women's health. The results are used... to plan health services and health education programs, and to do statistical studies of families, fertiliy, and health"
#
# The goal of the survey is to draw conclusions about a **population**. Specifically to investigate whether first babies tend to come late, as well as answer pther questions.
#
# Other concepts:
# A collected subset of the pupulation is called **sample**. The people who participate in a survey are called **respondents**. Each survey deployment is called a **cycle**.
#
# #### Types of studies
# * Cross-sectional study: captures a snapshot of a group at a point in time. Cross-sectional studies are meant to be **representative**, which means that every member of thje target population has an equal chance of participating.
# * Logitudinal study: observes a group repeatedly over a period of time.
#
# THE NSFG is not representative, is deliberately oversampled for three groups --Hispanics, African Americans and teenagers-- at rates higher than their representation in the U.S. population, in order to make sure that the number of respondents in each of these groups is large enough to draw valid statistical inferences.

# %% [markdown]
# # Importing Data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
# !ls
# Out:
# Chapter_1_Exploratory_Data_Analysis.ipynb
# Chapter1_Exploratory_Data_Analysis.ipynb

# %%
# !git clone https://github.com/AllenDowney/ThinkStats2
# Out:
# Cloning into 'ThinkStats2'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 2821 (delta 4), reused 8 (delta 3), pack-reused 2807
# Receiving objects: 100% (2821/2821), 172.51 MiB | 13.40 MiB/s, done.
# Resolving deltas: 100% (1604/1604), done.
# Checking out files: 100% (485/485), done.

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/ThinkStats2
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/ThinkStats2

# %%
# !ls
# Out:
# book  CONTRIBUTING.md  examples   LICENSE    setup.py	thinkplot    workshop
# code  environment.yml  homeworks  README.md  solutions	thinkstats2

# %%
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/ThinkStats2/code
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/ThinkStats2/code

# %%
# !ls
# Out:
# 1982NSFGData.dat.gz	      chap03soln.py   mystery2.dat
# 1995FemRespData.dat.gz	      chap04ex.ipynb  mystery3.dat
# 2002FemPreg.dat.gz	      chap05ex.ipynb  mystery4.dat
# 2002FemPreg.dct		      chap06ex.ipynb  mystery5.dat
# 2002FemResp.dat.gz	      chap06soln.py   mystery6.dat
# 2002FemResp.dct		      chap07ex.ipynb  mystery7.dat
# 2002Male.dat.gz		      chap07soln.py   mystery.py
# 2002Male.dct		      chap08ex.ipynb  normal.py
# 2006_2010_FemPreg.dat.gz      chap08soln.py   nsfg2.py
# 2006_2010_FemPregSetup.dct    chap09ex.ipynb  nsfg.py
# 2006_2010_FemResp.dat.gz      chap09soln.py   pandas_demos.ipynb
# 2006_2010_FemRespSetup.dct    chap10ex.ipynb  pandas_examples.ipynb
# 2006_2010_Male.dat.gz	      chap11ex.ipynb  PEP_2012_PEPANNRES_metadata.csv
# 2006_2010_MaleSetup.dct       chap12ex.ipynb  PEP_2012_PEPANNRES_with_ann.csv
# 2011_2013_FemPregData.dat.gz  chap12soln.py   populations.csv
# 2011_2013_FemPregSetup.dct    chap13ex.ipynb  populations.py
# ...

# %%
! python nsfg.py
# Out:
# (13593, 244)
# All tests passed.

# %%
import nsfg
df = nsfg.ReadFemPreg()
df.co
# Out:
#        caseid  pregordr  howpreg_n  ...  sest  cmintvw  totalwgt_lb
# 0           1         1        NaN  ...     9      NaN       8.8125
# 1           1         2        NaN  ...     9      NaN       7.8750
# 2           2         1        NaN  ...    12      NaN       9.1250
# 3           2         2        NaN  ...    12      NaN       7.0000
# 4           2         3        NaN  ...    12      NaN       6.1875
# ...       ...       ...        ...  ...   ...      ...          ...
# 13588   12571         1        NaN  ...    78      NaN       6.1875
# 13589   12571         2        NaN  ...    78      NaN          NaN
# 13590   12571         3        NaN  ...    78      NaN          NaN
# 13591   12571         4        NaN  ...    78      NaN       7.5000
# 13592   12571         5        NaN  ...    78      NaN       7.5000
#
# [13593 rows x 244 columns]

# %%
df.columns
# Out:
# Index(['caseid', 'pregordr', 'howpreg_n', 'howpreg_p', 'moscurrp', 'nowprgdk',
#        'pregend1', 'pregend2', 'nbrnaliv', 'multbrth',
#        ...
#        'laborfor_i', 'religion_i', 'metro_i', 'basewgt', 'adj_mod_basewgt',
#        'finalwgt', 'secu_p', 'sest', 'cmintvw', 'totalwgt_lb'],
#       dtype='object', length=244)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        caseid  pregordr  howpreg_n  ...  sest  cmintvw  totalwgt_lb
# 0           1         1        NaN  ...     9      NaN       8.8125
# 1           1         2        NaN  ...     9      NaN       7.8750
# 2           2         1        NaN  ...    12      NaN       9.1250
# 3           2         2        NaN  ...    12      NaN       7.0000
# 4           2         3        NaN  ...    12      NaN       6.1875
# ...       ...       ...        ...  ...   ...      ...          ...
# 13588   12571         1        NaN  ...    78      NaN       6.1875
# 13589   12571         2        NaN  ...    78      NaN          NaN
# 13590   12571         3        NaN  ...    78      NaN          NaN
# 13591   12571         4        NaN  ...    78      NaN       7.5000
# 13592   12571         5        NaN  ...    78      NaN       7.5000
#
# [13593 rows x 244 columns]>

# %%
# Validation
df.outcome.value_counts().sort_index()
# Out:
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: outcome, dtype: int64
